# %% [markdown]
# # Problem Set 1 (93 points)

# %% [markdown]
# ## Important information
# We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.

# %% [markdown]
# # Problem 1 (Theoretical tasks)  (36 pts)
#
# _1._
# - (1 pts) what are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{2} \leq \|x\|_{\infty} \leq C_2 \| x\|_{2}$ for any vector $x$
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.
#
# _2._
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. _Hint:_ SVD will help you.
# - (5 pts) Show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
# - (5 pts) Prove that if $\mathrm{rank}(A) = 1$, then $\| A \|_F  = \| A \|_2$.
# - (5 pts) Prove that $\| A B \|_F \le \| A \|_2 \| B \|_F$.
#
# _3._
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$
# - (3 pts) Compute SVD of the matrix analytically, i.e. provide the analytical expression for every natural $n$
#
# $$
# A = \begin{bmatrix}
# 1\\
# \sqrt{3}\\
# \sqrt{5}\\
# \vdots\\
# \sqrt{2n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$

# %% [markdown]
# # **Problem 1**
# ## **Problem 1.1**
# ### **Problem 1.1.1**
# Our inequality: $C_1 \|x\|_{2} \leq \|x\|_{\infty} \leq C_2 \| x\|_{2}$
#
# Vector norms are defined as:
# * $\|x\|_{2} = \sqrt{\sum_{i=1}^{n} |x_{i}|^{2}}$
# * $\|x\|_{\infty} = \max\limits_{1 \leq i \leq n}|x_{i}|$
#
# 1) Let's consider inequality $C_1 \|x\|_{2} \leq \|x\|_{\infty}$
#
# Applied vector norms we get $C_1 \sqrt{\sum_{i=1}^{n} |x_{i}|^{2}} \leq \max\limits_{1 \leq i \leq n}|x_{i}|$
#
# In order to define $C_1$, let vector $x$ consists of $\max\limits_{1 \leq i \leq n}|x_{i}|$, i.e. $x_{1} = x_{2} = \dotsc = x_{n} = max(x)$. In this case $\|x\|_{2} \rightarrow max$ and $\|x\|_{2} = \sqrt{n \cdot |x_{i}|^{2}} \implies C_1 \cdot \sqrt{n} \cdot |x_{i}| \leq |x_{i}| \implies C_1 \leq \frac{1}{\sqrt{n}}$
#
# 2) Let's consider inequality $\|x\|_{\infty} \leq C_2 \| x\|_{2}$
#
# Applied vector norms we get $\max\limits_{1 \leq i \leq n}|x_{i}| \leq C_2 \sqrt{\sum_{i=1}^{n} |x_{i}|^{2}}$
#
# In order to define $C_2$ we should minimize $\|x\|_{2}$, i.e. vector $x$ has to contain all zeros except one particular value $x_{i} \ne 0$. Then $\max\limits_{1 \leq i \leq n}|x_{i}| \leq C_2 \cdot |x_{i}|$. Ultimately, $\max\limits_{1 \leq i \leq n}|x_{i}| == |x_{i}| \implies C_2 \geq 1$
#
# *Answer is*: $C_1 \leq \frac{1}{\sqrt{n}}, C_2 \geq 1$
#
# ### **Problem 1.1.2**
# Need to prove $\| U A \|_F = \| A U \|_F = \| A \|_F$
#
# $U$ is an unitary matrix. So, $$U^{*}U = UU^{*} = I$$, where $I$ is an identity matrix.
#
# Frobenius norm is defined as $\|A\|_{F} = \sqrt{trace(A^{*}A)}$, where $trace(AB) = trace(BA)$.
#
# 1) $\|UA\|_{F} = \sqrt{trace((UA)^{*}UA)} = \sqrt{trace(A^{*}U^{*}UA)} = \sqrt{trace(A^{*}IA)} = \sqrt{trace(A^{*}A)} = \|A\|_{F}$
#
# 2) $\|AU\|_{F} = \sqrt{trace((AU)^{*}AU)} = \sqrt{trace(U^{*}A^{*}AU)}$
#
#
# Let matrix $U^{*}A^{*}A = B$ and $U=C$, then $trace(BC) = trace(CB) \implies \|AU\|_{F} = \sqrt{trace(UU^{*}A^{*}A)} = \sqrt{trace(A^{*}A)} = \|A\|_{F}$
#
# So, $\| U A \|_F = \| A U \|_F = \| A \|_F$. $Q.E.D$.
#
# ### **Problem 1.1.3**
# Need to prove $\| U A \|_2 = \| A U \|_2 = \| A \|_2$
#
# $2$-norm is defined as $\|A\|_{2} = \sqrt{\lambda_{max}(A^{*}A)}$
#
# 1) $\|UA\|_{2} = \sqrt{\lambda_{max}((UA)^{*}UA)} = \sqrt{\lambda_{max}(A^{*}U^{*}UA)} = \sqrt{\lambda_{max}(A^{*}IA)} = \sqrt{\lambda_{max}(A^{*}A)} = \|A\|_{2}$
#
# 2) Let's use definition of operator norms $$\|A\|_{p} = \sup_{x\ne0} \frac{\|Ax\|_{p}}{\|x\|_{p}}$$
#
# $\|AU\|_{2} = \sup_{x\ne0} \frac{\|AUx\|_{2}}{\|x\|_{2}}$
#
# Important mark: $\|Ux\|_{2} = \|x\|_{2}$
#
# $\|AU\|_{2} = \sup_{x\ne0} \frac{\|AUx\|_{2}}{\|Ux\|_{2}}$, where product of $Ux$ is a vector. Thus, let's substitute our product $Ux$ to vector $y \implies \|AU\|_{2} = \sup_{x\ne0} \frac{\|Ay\|_{2}}{\|y\|_{2}} = \|A\|_{2}$. $Q.E.D$.
#
# ## **Problem 1.2**
# ### **Problem 1.2.1**
#
# Need to prove $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$
#
# Matrix Frobenius norm and 2-norm are defined as:
# * $\|A\|_{2} = \delta_{max}(A)$
# * $\|A\|_{F} = \sqrt{\sum_{i=1}^{m}\sum_{j=1}^{n}|a_{i,j}|^{2}}$
#
# Let's describe singular value decomposition: $$A=U\Sigma V^{*}$$, where $U, V^{*}$ - unitary matrices, $\Sigma$ - diagonal matrix with singular values.
#
# Important mark: if $rank(A) = r \Rightarrow \delta_{r+1} = \dotsc = \delta_{k} = 0$
#
# Remark: All singular values in $\Sigma$ are sorted from $(1, 1)$ to $(n, n)$ in descending order.
#
# Let $rank(A) = r$. Then it is possible to get the next inequality:
#
# $\|U\Sigma V^{*}\|_{F} \leq \sqrt{r} \|A\|_{2} \Leftrightarrow \|\Sigma\|_{F} \leq \sqrt{r} \|A\|_{2}$
#
# $\sqrt(r) \geq \frac{\|\Sigma\|_{F}}{\|A\|_{2}}$, where $\|\Sigma\|_{F}$, $\|A\|_{2} \geq 0$. Consequently, it is possible to square this inequality.
#
# $r \geq \frac{\|\Sigma\|_{F}^{2}}{\|A\|_{2}^{2}}$, where $\|\Sigma\|_{F}^{2} = \sum_{i=1}^{m}\sum_{j=1}^{n}|a_{i,j}|^{2}$ - sum of singular values of the squared power and $\|\Sigma\|_{2}^{2} = \delta_{max}^{2}(A)$. Thus, it is able to represent our fraction in the form like: $$ r \geq \frac{x_{1,1}^{2} + x_{2, 2}^{2} + \dotsc x_{n, n}^{2}}{x_{1, 1}^{2}}$$, where $x_{1, 1}$ - maximal singular value, $n$ - number of singular values.
#
# It is possible to represent $r = n \cdot \frac{x_{1,1}^{2}}{x_{1,1}^{2}}$. Thus, let's perform our inequality in the following way: $$n \cdot \frac{x_{1,1}^{2}}{x_{1,1}^{2}} \geq \frac{x_{1,1}^{2}}{x_{1,1}^{2}} + \frac{x_{2,2}^{2}}{x_{1,1}^{2}} + \dotsc + \frac{x_{n, n}^{2}}{x_{1,1}^{2}}$$, where $x_{1, 1} \geq x_{2, 2} \geq \dotsc \geq x_{n, n}$
#
# It is obvious that left side is always greater or equal than right side, because $\frac{x_{2,2}^{2}}{x_{1,1}^{2}} \leq \dotsc \leq \frac{x_{n,n}^{2}}{x_{1,1}^{2}} \leq 1$. $Q.E.D$.
#
# ### **Problem 1.2.2**
#
# Need to show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$
#
# Suppose that there is a matrix $A$ like identity rectangular, i.e.
#
# $$
# a_{i,j} = \begin{cases} 1, i=j \leq k \\ 0, otherwise \end{cases}
# $$
#
# Example of matrix:
#
# \begin{pmatrix}
#   1 & 0 & \cdots & 0 \\
#   0 & 1 & \cdots & 0 \\
#   \vdots  & \vdots  & \ddots & \vdots \\
#   0 & 0 & \cdots & 1 \\
#   \vdots  & \vdots  & \ddots & \vdots \\
#   0 & 0 & \cdots & 0
#  \end{pmatrix}
#
#  Definition of matrix norms from the __Problem 1.2.1__:
# * $\|A\|_{2} = \delta_{max}(A)$
# * $\|A\|_{F} = \sqrt{\sum_{i=1}^{m}\sum_{j=1}^{n}|a_{i,j}|^{2}}$
#
# In this case $\|A\|_{F} = \sqrt{k \cdot 1}$, whereas $\|A\|_{2} = 1$ and $rank(A) = k$.
#
# To sum up, we have an equation $\sqrt{k} = \sqrt{k} \cdot 1$
#
# $Q.E.D.$
#
# ### **Problem 1.2.3**
# Need to prove if $\mathrm{rank}(A) = 1$, then $\| A \|_F  = \| A \|_2$.
#
# Take advantage of definition of matrix norms from the __Problem 1.2.1__:
# * $\|A\|_{2} = \delta_{max}(A)$
# * $\|A\|_{F} = \sqrt{\sum_{i=1}^{m}\sum_{j=1}^{n}|a_{i,j}|^{2}}$
#
# It is necessary to use singular value decomposition, which is also described in the __Problem 1.2.1__. After several transformations it is able to obtain the next equation: $\|A\|_{F} = \|U\Sigma V^{*}\|_{F} = \|\Sigma\|_{F}$, where $\Sigma$ is diagonal matrix with singular values in descending order.
#
# $rank(A) = 1 \implies \delta_{2} = \delta_{3} = \dotsc = 0$. So, we have only one singular value, which is also a maximal singular value of matrix $A$.
#
# In this way we can define $\|A\|_{F} = \|\Sigma\|_{F} = \sqrt{\sum_{i=1}^{m}\sum_{j=1}^{n}|a_{i,j}|^{2}} = |a_{1, 1}| = \delta_{max}(A) = \|A\|_{2}$. Q.E.D.
#
# ### **Problem 1.2.4**
#
# Need to prove $\|AB\| \leq \|A\|_{2} \|B\|_{F}$
#
# Singular value decomposition of matrix $A = U_{A}\Sigma_{A}V_{A}^{*}$
#
# Then, $\|U_{A}\Sigma_{A}V_{A}^{*}B\|_{F} \leq \|A\|_{2}\|B\|_{F}$
#
# After using preserving norm inequality has the form $\|\Sigma_{A}V_{A}^{*}B\|_{F} \leq \|A\|_{2}\|B\|_{F} \Leftrightarrow \|\Sigma_{A}V_{A}^{*}B\|_{F} \leq \|A\|_{2}\|V_{A}^{*}B\|_{F} $
#
# Let $V_{A}^{*}B = M$, then $\|\Sigma_{A}M\|_{F} \leq \|A\|_{2}\|M\|_{F}$
#
# Let's represent product of $\Sigma_{A}M$ in the form of element-wise product, i.e. $\|\Sigma_{A}M\|_{F} = \sqrt{\sum_{i=1}^{k}\sum_{j=1}^{n}|\delta_{i,j}m_{i,j}|^{2}}$, where $\|A\|_{2} = \delta_{max}(A) = \delta_{max}$ and $\|M\|_{F} = \sqrt{\sum_{i=1}^{k}\sum_{j=1}^{n}|m_{i,j}|^{2}}$
#
# Then, inequality will take the following form: $\sqrt{\sum_{i=1}^{k}\sum_{j=1}^{n}|\delta_{i,j}m_{i,j}|^{2}} \leq \delta_{max} \cdot \sqrt{\sum_{i=1}^{k}\sum_{j=1}^{n}|m_{i,j}|^{2}}$
#
# Left and right sides are greater or equal than zero, so it is possible to squared inequality. Then: $\sum_{i=1}^{k}\sum_{j=1}^{n}|\delta_{i,i}m_{i,j}|^{2} \leq \sum_{i=1}^{k}\sum_{j=1}^{n}\delta_{max}^{2} \cdot |m_{i,j}|^{2}$
#
# It is obvious that the right side is always greater or equal than the left side, because $\delta_{max} > \delta_{2, 2} > \dotsc > \delta_{i,i}$.
#
# So, $\|AB\| \leq \|A\|_{2} \|B\|_{F}. Q.E.D.$
#
#
#
# ## **Problem 1.3**
# ### **Problem 1.3.1**
#
# Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
#
# Need to find pseudoinverse $UU^{*}$.
#
# ### **Problem 1.3.2**
#
# Need to compute SVD for matrix A.
#
# $$
# A = \begin{bmatrix}
# 1\\
# \sqrt{3}\\
# \sqrt{5}\\
# \vdots\\
# \sqrt{2n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$
#
# Let's decompose matrix $A$. So, $A = U\Sigma V^{*}$.
#
# Let $A = x^\intercal y$, where $x, y \in \mathbb{R}^{n}$. So, $x = \begin{bmatrix}1 & \sqrt{3} & \sqrt{5} & \dotsc & \sqrt{2 \cdot n - 1}\end{bmatrix}$ and $y = \begin{bmatrix}1 & -1 & 1 & \dotsc & (-1)^{n}\end{bmatrix}$.
#
# In order to vector will be a left/right unitary it is necessary to normalize our vectors. It is important to use **eucledian norm**: $$\|x\|_{2} = \sqrt{\sum_{i=1}^{n}|x_{i}|^{2}}$$
#
# Let's find 2-norms of vectors $x, y$. Take advantage of arithmetic progression formula to calculate norm: $$S_{n} = \frac{a_{1} + a_{n}}{2} \cdot n$$
#
#
# $\|x\|_{2} = \sqrt{\frac{1 + 2\cdot n - 1}{2} \cdot n} = n$, where $a_{1} = 1, a_{n} = 2\cdot n - 1$
#
# $\|y\|_{2} = \sqrt{\frac{1 + 1^{2\cdot n}}{2} \cdot n} = \sqrt{n}$
#
# So, $\frac{x^\intercal}{\|x\|_{2}}$ and $\frac{y}{\|y\|_{2}}$ are left and right unitary matrices respectively. It is important to notice that the shape of left unitary matrix is equal $n\times 1$, whereas the shape of right unitary matrix is equal  $1\times n$.
#
# Let's substitute coefficients $\frac{1}{\|x\|_{2}} = \frac{1}{n} = C_{1}, \frac{1}{\|y\|_{2}} = \frac{1}{\sqrt{n}} = C_{2}$.
#
# So, let's create equation: $x^\intercal y = U\Sigma V^{*} \Leftrightarrow C_{1} x^\intercal \cdot \frac{1}{C_{1}\cdot C_{2}} \cdot C_{2}y = U\Sigma V^{*}$. Then $\fbox{$U=\frac{x^\intercal}{n}, \Sigma = n\sqrt{n}, V^{*}=\frac{y}{\sqrt{n}}$}$.
#
# So, singular value decomposition looks like:
#
# $$
# A = \begin{bmatrix}
# \frac{1}{n}\\
# \frac{\sqrt{3}}{n}\\
# \frac{\sqrt{5}}{n}\\
# \vdots\\
# \frac{\sqrt{2n-1}}{n}
# \end{bmatrix}
# \begin{bmatrix}
# n\sqrt{n}
# \end{bmatrix}
# \begin{bmatrix}
# \frac{-1}{\sqrt{n}} & \frac{1}{\sqrt{n}} & \frac{-1}{\sqrt{n}} & \ldots & \frac{(-1)^{n}}{\sqrt{n}}
# \end{bmatrix}
# $$

# %% [markdown]
# # Problem 2 (Matrix calculus) (12 pts)
#
# _1._ (10 pts) Consider the following function
#
# $$ F(U, V) = \frac{1}{2}\|X - UV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$ and $V \in \mathbb{R}^{k \times n}$ and $k < n$.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
# - (6 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion
#
# _2._ (2 pts) Derive analytical expression for the gradient of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %% [markdown]
# # Problem 2
# ## Problem 2.1
#
# We have
#
# $$ F(U, V) = \frac{1}{2}\|X - UV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$ and $V \in \mathbb{R}^{k \times n}$ and $k < n$.
#
# Let's use third approach via trace.
#
# $F(U, V) = \frac{1}{2}\|X - UV\|_F^2 = \frac{1}{2} trace((X - UV)^\intercal (X-UV)) =\frac{1}{2}trace((X^\intercal - V^\intercal U^\intercal)(X-UV)) = \frac{1}{2}trace(X^\intercal X - X^\intercal UV - V^\intercal U^\intercal X + V^\intercal U^\intercal UV) = \frac{1}{2}trace(V^\intercal U^\intercal UV - 2V^\intercal U^\intercal X + X^\intercal X) = \frac{1}{2}trace((UV)^\intercal UV) - trace((UV)^\intercal X) + \frac{1}{2}trace(X^\intercal X)$
#
# Define:
# 1. $trace((UV)^\intercal UV) = \sum_{i, j, k ,l} V_{i,j}^\intercal U_{j,k}^\intercal U_{k,l} V_{l,i}$
# 2. $trace((UV)^\intercal X) = \sum_{i, j, k} V_{i,j}^\intercal U_{j,k}^\intercal X_{k,i}$
#
# ### Problem 2.1.1
# $\nabla_{U}{F}$:
#
# **Firstly**, find $\frac{\partial trace((UV)^\intercal UV)}{\partial U}$
#
# It is equal to $\frac{\partial\sum_{i, j, k ,l} V_{i,j}^\intercal U_{k,j} U_{k,l} V_{l,i}}{\partial U_{k,j}} = 2UVV^\intercal$ ($U$ to second power)
#
# **Secondly**, find $\frac{\partial trace((UV)^\intercal X)}{\partial U}$
#
# It is equal to $\frac{\partial\sum_{i, j, k} V_{i,j}^\intercal U_{k,j} X_{k,l}}{\partial U_{k,j}} = XV^\intercal$
#
# **Thirdly**, find $\frac{\partial{\frac{1}{2}trace(X^\intercal X)}}{\partial U} = 0$
#
# $\fbox{$\frac{\partial F}{\partial U} = UVV^\intercal - XV^\intercal$}$
#
# ### Problem 2.1.2
# $\nabla_{V}{F}$:
#
# **Firstly**, find $\frac{\partial trace((UV)^\intercal UV)}{\partial V}$
#
# It is equal $\frac{\partial\sum_{i, j, k ,l} V_{j,i} U_{j,k}^\intercal U_{k,l} V_{l,i}}{\partial V_{j,i}} = 2U^\intercal UV$ ($V$ to second power)
#
# **Secondly**, find $\frac{\partial trace((UV)^\intercal X)}{\partial V}$
#
# It is equal to $\frac{\partial\sum_{i, j, k} V_{j,i} U_{j,k}^\intercal X_{k,l}}{\partial V_{j,i}} = U^\intercal X$
#
# **Thirdly**, find $\frac{\partial{\frac{1}{2}trace(X^\intercal X)}}{\partial V} = 0$
#
# $\fbox{$\frac{\partial F}{\partial V} = U^\intercal UV - U^\intercal X$}$
#
# ### Problem 2.1.3

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()

# %matplotlib inline
# plt.rc("text", usetex=True)

# %%
@jax.jit
def F(X, U, V):
    frobenius = jnp.linalg.norm(X - U @ V, 'fro')
    return 1/2 * (frobenius ** 2)

gradient_U = jax.grad(F, argnums=1)
gradient_V = jax.grad(F, argnums=2)

def create_matrix(n_rows: int, n_columns: int):
    return jax.random.normal(jax.random.PRNGKey(0), (n_rows, n_columns))

@jax.jit
def analytical_grad_to_U(X, U, V):
    return (U @ V - X) @ V.T

@jax.jit
def analytical_grad_to_V(X, U, V):
    return U.T @ (U @ V - X)

@jax.jit
def automatic_grad_to_U(X, U, V):
    return gradient_U(X, U, V)

@jax.jit
def automatic_grad_to_V(X, U, V):
    return gradient_V(X, U, V)

n = 1000
k = 500

X = create_matrix(n, n)
U = create_matrix(n, k)
V = create_matrix(k, n)

print('\nAnalytical gradient of the function F  with respect to U')
# %timeit analytical_grad_to_U(X, U, V).block_until_ready()

print('\nAutomatic gradient of the function F with respect to U')
# %timeit automatic_grad_to_U(X, U, V).block_until_ready()

print('\nAnalytical gradient of the function F  with respect to V')
# %timeit analytical_grad_to_U(X, U, V).block_until_ready()

print('\nAutomatic gradient of the function F with respect to V')
# %timeit automatic_grad_to_U(X, U, V).block_until_ready()


# class MatrixCalculus:

#   def __init__(self, n: int, k: int):
#     self.X = self.create_matrix(n, n)
#     self.U = self.create_matrix(n, k)
#     self.V = self.create_matrix(k, n)

#   def create_matrix(self, n_rows: int, n_columns: int):
#     return jax.random.normal(jax.random.PRNGKey(0), (n_rows, n_columns))
  
#   @partial(jax.jit, static_argnums=(0,))
#   def analytical_grad_to_U(self):
#     return (self.U @ self.V - self.X) @ self.V.T

#   @partial(jax.jit, static_argnums=(0,))
#   def analytical_grad_to_V(self):
#     return self.U.T @ (self.U @ self.V - self.X)

#   @partial(jax.jit, static_argnums=(0,))
#   def automatic_grad_to_U(self):
#     return gradient_U(self.X, self.U, self.V)

#   @partial(jax.jit, static_argnums=(0,))
#   def automatic_grad_to_V(self):
#     return gradient_V(self.X, self.U, self.V)
# Out:
# Analytical gradient of the function F  with respect to U
# 10 loops, best of 3: 36.1 ms per loop
#
# Automatic gradient of the function F with respect to U
# The slowest run took 5.13 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10 loops, best of 3: 38.4 ms per loop
#
# Analytical gradient of the function F  with respect to V
# 10 loops, best of 3: 35.5 ms per loop
#
# Automatic gradient of the function F with respect to V
# 10 loops, best of 3: 38.5 ms per loop

# %%
def calculate(n, k, key='analytical_U'):
    X = create_matrix(n, n)
    U = create_matrix(n, k)
    V = create_matrix(k, n)

    if key == 'analytical_U':
        t = %timeit -o -q analytical_grad_to_U(X, U, V).block_until_ready()

    elif key == 'automatic_U':
        t = %timeit -o -q automatic_grad_to_U(X, U, V).block_until_ready()

    elif key == 'analytical_V':
        t = %timeit -o -q analytical_grad_to_V(X, U, V).block_until_ready()

    elif key == 'automatic_V':
        t = %timeit -o -q automatic_grad_to_V(X, U, V).block_until_ready()

    return t.worst

def calculate_time(key, dimension, steps, const_value):
    if dimension == 'n':
        return [calculate(n=n, k=const_value, key=key) for n in steps]

    elif dimension == 'k':
        return [calculate(n=const_value, k=k, key=key) for k in steps]

# %%
n_steps = jnp.linspace(600, 10000, 16, dtype='int32')
analytical_U_n = calculate_time('analytical_U', 'n', n_steps, 500)
automatic_U_n = calculate_time('automatic_U', 'n', n_steps, 500)
analytical_V_n = calculate_time('analytical_V', 'n', n_steps, 500)
automatic_V_n = calculate_time('automatic_V', 'n', n_steps, 500)

# %%
fig = plt.figure(figsize=(22, 8))
ax = fig.add_subplot(111)    
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

ax1.scatter(n_steps, analytical_U_n, label='analytical - dF/dU')
ax1.scatter(n_steps, automatic_U_n, label='automatic - dF/dU')
ax2.scatter(n_steps, analytical_V_n, label='analytical - dF/dV')
ax2.scatter(n_steps, automatic_V_n, label='automatic - dF/dV')

ax.set_title(r'Dependence of worst running time per iteration and dimension N, where $k: const =500$', fontsize=18)
ax.set_xlabel('N dimension', fontsize=20)
ax.set_ylabel('Worst running time', fontsize=20)

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)

ax1.legend(prop={'size': 16})
ax2.legend(prop={'size': 16})

# %% [markdown]
# We are able to conclude that each plot has squared growth. It seems that, approaches to calculate gradients are not very different in terms of computational complexity.

# %%
k_steps = jnp.linspace(100, 4500, 18, dtype='int32')
n = 5000

analytical_U_k = calculate_time('analytical_U', 'k', k_steps, n)
automatic_U_k = calculate_time('automatic_U', 'k', k_steps, n)
analytical_V_k = calculate_time('analytical_V', 'k', k_steps, n)
automatic_V_k = calculate_time('automatic_V', 'k', k_steps, n)

# %%
fig = plt.figure(figsize=(22, 8))
ax = fig.add_subplot(111)    
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

ax1.scatter(k_steps, analytical_U_k, label='analytical - dF/dU')
ax1.scatter(k_steps, automatic_U_k, label='automatic - dF/dU')
ax2.scatter(k_steps, analytical_V_k, label='analytical - dF/dV')
ax2.scatter(k_steps, automatic_V_k, label='automatic - dF/dV')

ax.set_title(r'Dependence of worst running time per iteration and dimension K, where $n: const =5000$', fontsize=18)
ax.set_xlabel('K dimension', fontsize=20)
ax.set_ylabel('Worst running time', fontsize=20)

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)

ax1.legend(prop={'size': 16})
ax2.legend(prop={'size': 16})

# %% [markdown]
# We are able to conclude that each plot has linear dependence with small fluctuations with respect to number of columns and worst running time per iteration.
#
# It is noticed that approaches carry out similar number of iterations per seconds to calculate matrix norms.

# %% [markdown]
# ### Final conclusion about plots
#
# When dimension 'row' is const - we have linear dependence with respect to number of columns and worst running time per iteration, whereas we have dimension 'columns' as const - it is observed that plots have squared growth with respect to quantity of rows and worst running time per iteration.

# %% [markdown]
# ## Problem 2.2
#
# Need to derive analytical expression for the gradient of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$ where $A$ is symmetric matrix.
#
# Let $(Ax, x)=u(x)$ and $(x,x) = v(x)$. Then gradient of the function $R'(x) = \frac{u'v - v'u}{v^{2}}$
#
# Product $(Ax, x)$ is able to be defined as element-wise product $\sum_{i=1}^{m}\sum_{j=1}^{n}a_{i,j}x_ix_j$ and $(x,x)$ is capable of to defined as $\sum_{i=1}^{m}x_i^2$.
#
# 1. $\frac{\partial u}{\partial x_k} = 2Ax$
# 2. $\frac{\partial v}{\partial x_k} = 2x$
#
# Thus, $\fbox{$R'(x) = \frac{2Ax(x,x) - 2x(Ax,x)}{(x,x)^2} = \frac{2[Ax(x,x) - x(Ax,x)]}{(x,x)^2}$}$

# %% [markdown]
# # Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)
#
# In this problem we consider the neural network that performs classification of the dataset of images.
# Any neural network can be considered as composition of simple linear and non-linear functions.
# For example, a neural network with 3 layers can be represented as
#
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy.
# Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed.
# The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# #### Zero step: install PyTorch
#
# - Follow the steps in [official instructions](https://pytorch.org/get-started/locally/)

# %% [markdown]
# #### First step: download CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ...
# Extracting ./cifar-10-python.tar.gz to ./

# %% [markdown]
# #### Check what images are we going to classify

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
#  ship  deer  bird truck  frog   car  frog   car

# %% [markdown]
# ### Second step: neural network architecture
#
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them.
# To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch.
# More details about neural networks you will study in the *Deep learning* course in one of the upcoming term

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.fc2 = nn.Linear(1000, 1000)
        self.fc3 = nn.Linear(1000, 1000)
        self.fc4 = nn.Linear(1000, 1000)
        self.fc5 = nn.Linear(1000, 1000)
        self.fc6 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.fc2(x)
        x = self.ReLU(x)
        x = self.fc3(x)
        x = self.ReLU(x)
        x = self.fc4(x)
        x = self.ReLU(x)
        x = self.fc5(x)
        x = self.ReLU(x)
        x = self.fc6(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Implement functions for training and testing after every sweep over all dataset entries

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# ### Set parameters for training and print intermediate loss values

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Third step: run training with the [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document) optimization method
#
# If your laptop is not very fast, you will wait some time till training is finished.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.304266
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 2.019302
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.680705
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.652985
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.803666
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.707490
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.660490
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.709324
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.644287
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.582324
#
# Test set: Average loss: 1.6200, Accuracy: 4309/10000 (43%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.564055
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.741747
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.704086
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.499888
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.417250
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.439309
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.718217
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.587252
# ...

# %% [markdown]
# Now we have somehow trained neural network and we are ready to perform compression of the weigths in the fully-connected layers.

# %% [markdown]
# - (3 pts) Compute SVD of the matrix $1000 \times 1000$, which corresponds to a weight matrix $A$ in any layer of the trained neural network of the appropriate dimension. To find more information about accessing this matrix please refer to [PyTorch manual](https://pytorch.org/docs/stable/index.html).
# Plot decaying of the singular values like it was shown in the lecture. What conclusion can you make?
# - (17 pts) Create a new model, which is an analogue to the class ```Net```, but with some significant distinctions.
# It takes as input parameters the instance of the class ```Net``` and compression rank $r > 0$.
# After that, this model has to compress all matrices $A$ in fully-connected layers with SVD using first $r$ singular vectors and singular values.
# Pay attention to efficient storing of compress representation of the layers.
# Also ```forward``` method of your new model has to be implemented in a way to use compressed representation of the fully-connected layers in the most efficient way. In all other aspects it has to reproduce ```forward``` method in the original non-compressed model (number of layers, activations, loss function etc).
# - (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank $r$.
# Also plot dependence of time to compute inference on the compression rank $r$.
# Explain obtained results.
# To measure time, use [%timeit](https://docs.python.org/3.6/library/timeit.html) with necessary parameters (examples of using this command see in lectures)
#
# - (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called fine-tuning. We ask you make this fine-tuning of your compressed model during from 1 to 5 epoch and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results

# %% [markdown]
# ## Problem 3.1

# %%
def decaying(layer):
    u, s, v = jnp.linalg.svd(layer.weight.detach().numpy())
    return s/s[0]

decaying_fc2 = decaying(model.fc2)
decaying_fc3 = decaying(model.fc3)
decaying_fc4 = decaying(model.fc4)
decaying_fc5 = decaying(model.fc5)

# %%
plt.figure(figsize=(12,8))

plt.semilogy(decaying_fc2, label='svd_decay_fc2')
plt.semilogy(decaying_fc3, label='svd_decay_fc3')
plt.semilogy(decaying_fc4, label='svd_decay_fc4')
plt.semilogy(decaying_fc5, label='svd_decay_fc5')

plt.ylabel(r"$\sigma_i / \sigma_0$", fontsize=24)
plt.xlabel(r"Singular value index, $i$", fontsize=24)
plt.grid(True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='lower left', prop={'size': 18})

# %% [markdown]
# The more detailed study from the graph reveals that each linear layer $1000\times 1000$ after singular value decomposition has the pretty same fraction between singular values.
#
# First 70-80 singular values significantly greater than rest of singular values. Consequently, they apparently the most substantial values and ultimately are able to be compression rank value in net.
#
# Singular values from 80 to 200 less than $10\%$ and 200-850 values less than $1\%$. This indicates that matrix capable to be approximated by $850 \times 850$. Also it seems to me that matrix $200 \times 200$ will provide a quite good results.

# %% [markdown]
# ## Problem 3.2

# %%
class AnalogueNet(nn.Module):

    def __init__(self, model, compression_rank):

        super(AnalogueNet, self).__init__()

        self.model = model
        self.r = compression_rank
        self.ReLU = self.model.ReLU

        self.fc2_layer = self.compress_layer(self.model.fc2)
        self.fc3_layer = self.compress_layer(self.model.fc3)
        self.fc4_layer = self.compress_layer(self.model.fc4)
        self.fc5_layer = self.compress_layer(self.model.fc5)

    def compress_layer(self, layer):
        layer_data = layer.weight.data
        u, s, v = torch.svd(layer_data, some=True)
        u, s, v = u[:, :self.r], s[:self.r], v[:, :self.r]

        layer_v = nn.Linear(1000, self.r, bias=False) #1000 x r
        layer_s = nn.Parameter(s) #r x r
        layer_u = nn.Linear(self.r, 1000, bias=True) #r x 1000

        with torch.no_grad():
            weights_v = torch.transpose(v, dim0=0, dim1=1)
            layer_v.weight.copy_(weights_v)

            layer_u.weight.copy_(u)
            layer_u.bias.copy_(layer.bias.data)

        return {'v': layer_v, 's': layer_s, 'u': layer_u}

    @staticmethod
    def linear_multiply(x, layer):
        layer_u = layer['u']
        layer_s = layer['s']
        layer_v = layer['v']

        x = layer_v(x) #Vx
        x = layer_u(layer_s * x) # USV_x
        return x

    def forward(self, x):

        #Input layer
        x = self.model.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)

        #FC2 layer
        x = self.linear_multiply(x, self.fc2_layer)
        x = self.ReLU(x)

        #FC3 layer
        x = self.linear_multiply(x, self.fc3_layer)
        x = self.ReLU(x)

        #FC4 layer
        x = self.linear_multiply(x, self.fc4_layer)
        x = self.ReLU(x)

        #FC5 layer
        x = self.linear_multiply(x, self.fc5_layer)
        x = self.ReLU(x)

        #Output layer
        x = self.model.fc6(x)
        return F.log_softmax(x, dim=1)

model1 = AnalogueNet(model, 350)
test(model1, test_loader)
# Out:
# Test set: Average loss: 1.3508, Accuracy: 5337/10000 (53%)

# %% [markdown]
# ## Problem 3.3

# %%
def get_accuracy(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    return correct / len(test_loader.dataset)

# %%
r_steps_sign = jnp.linspace(10, 60, 8, dtype='int32')
r_steps_rest = jnp.linspace(60, 1000, 14, dtype='int32')
r_steps = jnp.hstack((r_steps_sign, r_steps_rest))

accuracy = [get_accuracy(AnalogueNet(model, r), test_loader) for r in r_steps]
# Out:
# Test set: Average loss: 1.6169, Accuracy: 4429/10000 (44%)
#
#
# Test set: Average loss: 1.5355, Accuracy: 4962/10000 (50%)
#
#
# Test set: Average loss: 1.4516, Accuracy: 5155/10000 (52%)
#
#
# Test set: Average loss: 1.4141, Accuracy: 5241/10000 (52%)
#
#
# Test set: Average loss: 1.3888, Accuracy: 5268/10000 (53%)
#
#
# Test set: Average loss: 1.3793, Accuracy: 5293/10000 (53%)
#
#
# Test set: Average loss: 1.3780, Accuracy: 5289/10000 (53%)
#
#
# Test set: Average loss: 1.3709, Accuracy: 5305/10000 (53%)
#
#
# Test set: Average loss: 1.3709, Accuracy: 5305/10000 (53%)
#
#
# Test set: Average loss: 1.3489, Accuracy: 5325/10000 (53%)
#
#
# Test set: Average loss: 1.3502, Accuracy: 5346/10000 (53%)
#
#
# Test set: Average loss: 1.3495, Accuracy: 5336/10000 (53%)
#
#
# Test set: Average loss: 1.3507, Accuracy: 5337/10000 (53%)
#
#
# Test set: Average loss: 1.3507, Accuracy: 5326/10000 (53%)
#
#
# Test set: Average loss: 1.3495, Accuracy: 5324/10000 (53%)
#
#
# ...

# %%
plt.figure(figsize=(12, 8))

plt.scatter(r_steps, accuracy)

plt.xlabel(r'Compression rank $r$', fontsize=20)
plt.ylabel('Accuracy', fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.title(r'Dependence of test accuracy on the number of parameters in the compressed model ($r$)', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Dependence of test accuracy on the number of parameters in the compressed model ($r$)')

# %% [markdown]
# This plot illustrates that with increasing the compression rank from $1$ to $100$ accuracy rockets from $0.44$ to $0.53$, then accuracy stabilizies at the mark $0.54$ in range $100$ to $1000$ and looks like plateau.
#
# Thus, definetely, compression rank at the mark $100-200$ looks like an optimal value.

# %%
def special_for_timeit(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    return correct / len(test_loader.dataset)

# %%
def calculate_time_test(r):
    global current_model
    current_model = AnalogueNet(model, r)
    t = %timeit -o -q special_for_timeit(current_model, test_loader)
    return t.worst

time_results = [calculate_time_test(r) for r in r_steps]

# %%
plt.figure(figsize=(12, 8))

plt.scatter(r_steps, time_results)

plt.xlabel(r'Compression rank $r$', fontsize=20)
plt.ylabel('Worst running time', fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.title(r'Dependence of running time on the number of parameters in the compressed model ($r$)', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Dependence of running time on the number of parameters in the compressed model ($r$)')

# %% [markdown]
# This graph shows that compression rank and running time have linear dependence. The more compression rank, the longer running time per iterations. It is connected with the fact, that matrix size $n$ is fixed and we have product $r \cdot n$. So, the complexity of one layer is $O(rn)$.

# %% [markdown]
# ## Problem 3.4

# %%
model_r = AnalogueNet(model, 150)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

epochs = 3

for epoch in range(1, epochs + 1):
    train(model_r,  train_loader, optimizer, epoch)
    test(model_r, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 0.985096
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 0.993918
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 0.945832
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 0.741679
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 0.970817
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.087935
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 0.857212
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 0.957245
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 0.873628
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 0.831993
#
# Test set: Average loss: 1.3752, Accuracy: 5544/10000 (55%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.719063
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 0.790574
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 0.662103
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.056402
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 0.823262
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 0.911365
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.010535
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 0.989318
# ...

# %% [markdown]
# It is observed that accuracy has increased to $2\%$ and average loss generally has increased too.

# %% [markdown]
# ## Problem 4. «Reducio!» (15 pts)

# %% [markdown]
# Hermione Granger is well versed in all magical disciplines. In particular, she is a great expert in Numerical Linear Algebra and JAX.
#
# She has invited Harry Potter to play the game.
#
# Hermione chooses a number $r \in [1, 95]$ and two matrices $W_1 \in \mathbb{R}^{r \times 100}$ and $W_2 \in \mathbb{R}^{100 \times r}$.
# Harry can tell her any 100-dimensional vector $x$, and Hermione gives Harry the result of
#
# $$
# \sin(W_2 \cos(W_1 x)),$$
#
# where trigonometric functions are applied element-wise.
# This result is also a 100-dimensional vector.
#
# Not to lose, Harry should guess what number $r$ Hermione has chosen.
# Harry knows the python language, but he is an absolute layman in algebra. Please, help him to get at least 95% correct answers!
#
# <i> Hint 1: SVD might help you, but use it wisely! </i>
#
# <i> Hint 2: Suppose that a special magic allows you to compute gradients through automatic differentiation in JAX. You can also estimate gradients via finite differences, if you want it.</i>
#
# <i> Hint 3: You can estimate the matrix rank using simple heuristics.
#
# You should write code into the `harry_answers` function. Good luck!

# %%
import jax.numpy as jnp
import jax
import numpy as np
import random

class Game:
    def __init__(self, key):
        # key is a jax.random.PRNGKey
        self.key = key
        return

    def hermione_chooses_r_and_W(self):
        self.r = random.randint(1, 95)
        self.key, subkey = jax.random.split(self.key)
        self.W1 = jax.random.uniform(subkey, (self.r, 100), maxval=100., minval=0., dtype=jnp.float32)
        self.key, subkey = jax.random.split(self.key)
        self.W2 = jax.random.uniform(subkey, (100, self.r), maxval=100., minval=0., dtype=jnp.float32)

    def hermione_computes_function(self, x):
        return jnp.sin(self.W2 @ jnp.cos(self.W1 @ x))

    def harry_answers(self):
        n_rows = 100
        m = 100

        matrix = jax.random.normal(jax.random.PRNGKey(0), (n_rows, m))
        compute_scalar_func = lambda x: jax.random.choice(jax.random.PRNGKey(713),\
                                                    self.hermione_computes_function(x))
    
        gradient_f = jax.grad(compute_scalar_func, argnums=0)
        gradient_matrix = jnp.apply_along_axis(gradient_f, 1, matrix) / m ** 0.5
        u, s, v = jnp.linalg.svd(gradient_matrix)
        r = sum(1 if value // 1 else 0 for value in s)

        return r
    
    def play(self, n_rounds, verbose=True):
        # n_rounds: a number of rounds of the game
        # verbose: print or not the result of each round
        n_right_answers = 0
        for _ in range(n_rounds):
            self.hermione_chooses_r_and_W()
            r = self.harry_answers()
            if abs(r - self.r) == 0:
                if verbose:
                    print("Good job! The true answer is {}, Harry's answer is {}!".format(self.r, r))
                n_right_answers += 1
            else:
                if verbose:
                    print("Harry's answers is {}, but the true answer is {} :(".format(r, self.r))
        if float(n_right_answers) / n_rounds > 0.95:
            print('Well done: {}/{} right answers!'.format(n_right_answers, n_rounds))
        else:
            print('Only {}/{} right answers :( Work a little more and you will succeed!'.format(
                n_right_answers, n_rounds))

# %%
key = jax.random.PRNGKey(713)
game = Game(key)
game.play(n_rounds=100, verbose=True)
# Out:
# Good job! The true answer is 36, Harry's answer is 36!
# Good job! The true answer is 55, Harry's answer is 55!
# Good job! The true answer is 5, Harry's answer is 5!
# Good job! The true answer is 78, Harry's answer is 78!
# Good job! The true answer is 71, Harry's answer is 71!
# Good job! The true answer is 42, Harry's answer is 42!
# Good job! The true answer is 14, Harry's answer is 14!
# Good job! The true answer is 15, Harry's answer is 15!
# Good job! The true answer is 5, Harry's answer is 5!
# Good job! The true answer is 24, Harry's answer is 24!
# Good job! The true answer is 14, Harry's answer is 14!
# Good job! The true answer is 72, Harry's answer is 72!
# Good job! The true answer is 46, Harry's answer is 46!
# Good job! The true answer is 21, Harry's answer is 21!
# Good job! The true answer is 30, Harry's answer is 30!
# Good job! The true answer is 55, Harry's answer is 55!
# Good job! The true answer is 92, Harry's answer is 92!
# ...

# %% [markdown]
# # Problem 5 (Bonus)
#
# 1. The norm is called absolute if $\|x\|=\| \lvert x \lvert \|$ holds for any vector $x$, where $x=(x_1,\dots,x_n)^T$ and $\lvert x \lvert = (\lvert x_1 \lvert,\dots, \lvert x_n \lvert)^T$. Give an example of a norm which is not absolute.
#
# 2. Write a function ```ranks_HOSVD(A, eps)```
# that calculates Tucker ranks of a d-dimensional tensor $A$ using High-Order SVD (HOSVD) algorithm, where ```eps``` is the relative accuracy in the Frobenius norm between the approximated and the initial tensors. Details can be found [here](http://ca.sandia.gov/~tgkolda/pubs/pubfiles/TensorReview.pdf) on Figure 4.3.
# ```python
# def ranks_HOSVD(A, eps):
#       return r #r should be a tuple of ranks r = (r1, r2, ..., rd)
# ```

# %%
import numpy as np

a = np.array([[2, 0],
              [0, 2],
              [0, 0],
              [0, 0]])

np.linalg.norm(a, 2)
# Out:
# 2.0
